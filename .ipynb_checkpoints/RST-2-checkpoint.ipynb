# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
from statsmodels.tsa.stattools import adfuller, pacf, acf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import het_white, het_breuschpagan
import numpy as np
from numpy import polyfit
from scipy import stats
import RegscorePy as rp
from numpy import sqrt
from statsmodels.tsa.arima_model import ARIMA, ARIMAResults
import itertools
import chow_test
# %matplotlib inline

# %%
df = pd.read_csv('./data/RTS-history-USA.csv')
df = df[::-1]

# %%
series = np.array([i for i in df.Open[::25]])
series_dates = np.array([i for i in df.index[::25]])

# %%
draw = plt.plot

# %% [markdown]
# ### Экспоненциальное сглаживание

# %%
def exponential_smoothing(series, alpha):
    result = np.array([series[0]]) # first value is same as series
    for n in range(1, len(series)):
        result = np.append(result, alpha * series[n] + (1 - alpha) * result[n-1])
    
    res = 0
    for s, r in zip(series, result):
        res += (s - r) ** 2
    return result

# %% [markdown]
# ### Полином k-степени (поиск КФ тренда)

# %%
def get_polyfit(series, k, kf_out=False):
    p = polyfit(range(len(series)), series, k)
    if kf_out:
        for i in p:
            print(round(i, 4))
    return p

# %% [markdown]
# ### Поиск самого тренда по КФ

# %%
def find_trend_by_kf(p, out=False):
    pf = np.poly1d(p)
    if out:
        print(pf(range(len(series))))
    return pf(range(len(series)))

# %% [markdown]
# ### Поиск автокорреляции

# %%
def find_autocorr(seq, a=1, b=25):
    lags = []
    for lag in range(a, b+1):
        res_lag = pearsonr(seq[: -lag], seq[lag:])[0]
        lags.append(res_lag)
    return lags

# %% [markdown]
# ### Поиск КФ Акаике

# %%
def find_aic(array1, array2, k=5):
    a = array1.copy()
    b = array2.copy()
    if not isinstance(a, list):
        a = a.tolist()
    if not isinstance(b, list):
        b = b.tolist()
    return rp.aic.aic(a, b, k) / len(a)

# %% [markdown]
# ### Перебор КФ ARIMA

# %% [markdown]
# ### Сам график и сглаживания

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(series, label='Оригинал', color='000', linewidth=3)
for a in [.05, .25, .5, .75, .95]:
    result = exponential_smoothing(series, a)
    plt.plot(result, label=str(a))
plt.legend()
plt.show()

# %%
plt.plot(find_autocorr(exponential_smoothing(series, .5)));

# %% [markdown]
# ### Тест фуллера на стационарность ряда

# %%
adfuller(series)
# Out:
# (-2.670316461994629,
#  0.07931716496293206,
#  0,
#  112,
#  {'1%': -3.4901313156261384,
#   '5%': -2.8877122815688776,
#   '10%': -2.5807296460459184},
#  1212.2077258437034)

# %% [markdown]
# ### Поиск и отображение тренда графика

# %%
trend_line = find_trend_by_kf(get_polyfit(series, 4))
fig = plt.figure(figsize=(14, 8))
plt.plot(series, label='Оригинал')
plt.plot(trend_line, label='Полином')
plt.legend()
plt.show()

# %% [markdown]
# ### Расчет КФ детерминации

# %%
pl = find_trend_by_kf(get_polyfit(series, 4))
mean = series.mean()

# %%
top = ((pl-mean)**2).sum()
bottom = ((series-mean)**2).sum()
kf_determ = top/bottom
kf_determ
# Out:
# 0.805586569565061

# %% [markdown]
# ### Скорректированный КФ детерм

# %%
kf_determ_adj = 1 - (1 - kf_determ)*((len(series)-1)/(len(series)-5))
kf_determ_adj
# Out:
# 0.7983860721415448

# %% [markdown]
# ### Значимость КФ автокорреляции 2-го порядка

# %%
kf2 = find_autocorr(exponential_smoothing(series, .5))[1]
kf2 / (1-kf2**2/(len(series)-2))**.5
# Out:
# 0.9338383925415732

# %%
df3 = pd.read_csv('./data/RTS-history-USA.csv', parse_dates=True, index_col='Date')
df3 = df3[::-1][::25]
df3.head()
# Out:
#             Open
# Date
# 2009-01-11   631
# 2009-02-13   611
# 2009-03-24   737
# 2009-04-28   803
# 2009-06-04  1125

# %% [markdown]
# ### Декомпозиция

# %%
import statsmodels.api as sm

dta = df3.copy()
# deal with missing values. see issue
dta.Open.interpolate(inplace=True)

res = sm.tsa.seasonal_decompose(dta.Open, period=10)
res.plot();

# %% [markdown]
# ### Нахождение остатков после вычитания тренда

# %%
remains = series - trend_line

# %%
plt.plot(remains);
plt.show()
fig, ax = plt.subplots()
ax.plot(remains, marker='o', color='#f4b', linewidth=.1);
ax.hlines(0, -5, 120);

# %% [markdown]
# ### Критерий Фишера для уравнения тренда

# %%
(kf_determ/(1-kf_determ))*(len(series)-5)/4
# Out:
# 111.87929419071503

# %% [markdown]
# ## Значимость КФ регрессии по Стьюденту

# %% [markdown]
# ![data1.png](attachment:data1.png)

# %% [markdown]
# ### Критерий Шварца

# %%
rp.bic.bic(series.tolist(), trend_line.tolist(), 5)/len(series)
# Out:
# 9.964980051513505

# %%
np.log((remains ** 2).sum()/len(series))+5 * np.log(len(series))/len(series)
# Out:
# 9.964980051513505

# %% [markdown]
# ### Критерий Акаике

# %%
rp.aic.aic(series.tolist(), trend_line.tolist(), 5)/len(series)
# Out:
# 9.84429917457933

# %%
plt.plot(find_autocorr(remains), marker='o', linewidth=.2);

# %% [markdown]
# ### Критерий Жакка-Бера на нормальность распределения

# %%
stats.jarque_bera(remains)
# Out:
# (0.5095735668305718, 0.7750817406258271)

# %% [markdown]
# ### РС критерий на нормальность распределения

# %%
(remains.max() - remains.min()) / ((remains**2).sum()/len(series)-1)**.5
# Out:
# 5.085495701916399

# %% [markdown]
# ### Тест Дарбина Уотсона на автокорреляцию

# %%
# Сравнить с таблицей!

# %%
dw = 0
for t in range(1, len(remains)):
    dw += (remains[t]-remains[t-1])**2
dw /= (remains**2).sum()
dw
# Out:
# 0.7705080573236872

# %% [markdown]
# ### Тест на значимость КФ автокорреляции

# %%
kf = find_autocorr(remains, 1, 1)[0]
sqrt((kf**2)/(1-kf**2)*(len(remains)-2))
# Out:
# 8.193201354824389

# %% [markdown]
# ### Тест на равенство средних

# %%
stats.ttest_ind(series[:60], series[60:])
# Out:
# Ttest_indResult(statistic=6.430267317147217, pvalue=3.3086141740613716e-09)

# %%
# Поскольку у нас p-value очень мало, то гипотеза h0 - о равенстве средних отвергается

# %%
p1 = remains[:55]
p2 = remains[55:]
abs(p1.mean() - p2.mean()) / sqrt(np.var(p1)/len(p1) + np.var(p2)/len(p2))
# Out:
# 0.7148925714768324

# %% [markdown]
# ### Тест на гетероскедастичность (Гольфельд Квандт)

# %% [markdown]
# ### ARIMA

# %%
fig, ax = plt.subplots(figsize=(18, 10))
ax.plot(remains, label='Orig', linewidth=3)

min_aic = float('inf')
min_params = ()
min_mfit = None
# 7 0 2 / 1 1 1 / 7 0 8 - наилучшие
for p, d, q in itertools.product((7,), (0,), (8, )):
    model = ARIMA(remains, order=(p, d, q))
    try:
        mfit = model.fit()
    except: continue
    res_aic = find_aic(series[d:], series[d:] - mfit.resid)
    if res_aic < min_aic:
        min_aic = res_aic
        min_params = p, d, q
        min_mfit = mfit
    print(p, d, q, res_aic)
print('Min', min_params, min_aic)
#     pd.DataFrame(mfit.resid).plot(ax=ax)
#     plt.show()
# Out:
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# 7 0 8 9.156409597138602
# Min (7, 0, 8) 9.156409597138602

# %%
mfit.arparams
# Out:
# array([ 0.91147226,  0.2277196 , -0.4282041 ,  0.17270712,  0.04720058,
#         0.51243451, -0.61617799])

# %%
fig, ax = plt.subplots(figsize=(15, 10))
ax.plot(trend_line + mfit.resid)
ax.plot(series);

# %%
plot_acf(remains - mfit.resid);

# %%
plot_pacf(remains - mfit.resid);

# %% [markdown]
# ###  Q-test Льюинга Бокса для проверки гипотезы о случайности остатков

# %%
q_test = acf(mfit.resid, qstat=True, fft=False)
q_df = pd.DataFrame({'Q-stat': q_test[1], 'p-value': q_test[2]})
q_df['Q-stat'].plot()
plt.show()
q_df['p-value'].plot();

# %% [markdown]
# ### Тест Дики Фуллера на стационарность остатков

# %% [markdown]
# ###### Ряд стационарен

# %%
test_df = adfuller(remains)
if test_df[0] > test_df[4]['5%']:
    print('Ряд нестационарен')
else:
    print('Ряд стационарен')
test_df
# Out:
# Ряд стационарен
# (-5.130422100748794,
#  1.217307664803825e-05,
#  0,
#  112,
#  {'1%': -3.4901313156261384,
#   '5%': -2.8877122815688776,
#   '10%': -2.5807296460459184},
#  1197.077681342571)

# %% [markdown]
# ## Поскольку все значения p-value больше 0.05, это свидетельствует о том, что гипотеза об отсутствии автокорреляции не отвергается (на уровне значимости 5%)

# %% [markdown]
# #### p - 1,5

# %% [markdown]
# #### q - 1,2,6,7

# %%
plt.plot(pacf(remains)[:10], marker='o', label='PACF')
plt.plot(acf(remains, fft=False)[:10], marker='s')
plt.plot([0]*10)
plt.show();
# Out:
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# ### Тесты на гомоскедантичность (p-value < 0.05 - гетероскедантичность?)

# %%
test_bartlett = stats.bartlett(remains, range(len(remains)))
test_levene = stats.levene(remains, range(len(remains)))
print(test_bartlett)
print(test_levene)
# Out:
# BartlettResult(statistic=169.41630151628857, pvalue=9.923235819367831e-39)
# LeveneResult(statistic=96.43696551179367, pvalue=3.69259124387947e-19)

# %%
mfit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  113
# Model:                     ARMA(7, 8)   Log Likelihood                -669.769
# Method:                       css-mle   S.D. of innovations             83.560
# Date:                Mon, 09 Mar 2020   AIC                           1373.538
# Time:                        20:45:09   BIC                           1419.904
# Sample:                             0   HQIC                          1392.353
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1611      0.743     -0.217      0.828      -1.617       1.295
# ar.L1.y        0.9115      0.140      6.509      0.000       0.637       1.186
# ar.L2.y        0.2277      0.188      1.213      0.225      -0.140       0.596
# ar.L3.y       -0.4282      0.131     -3.264      0.001      -0.685      -0.171
# ar.L4.y        0.1727      0.156      1.106      0.269      -0.133       0.479
# ar.L5.y        0.0472      0.171      0.276      0.782      -0.288       0.382
# ar.L6.y        0.5124      0.139      3.699      0.000       0.241       0.784
# ar.L7.y       -0.6162      0.086     -7.177      0.000      -0.784      -0.448
# ma.L1.y       -0.5102      0.164     -3.106      0.002      -0.832      -0.188
# ma.L2.y       -0.5246      0.133     -3.952      0.000      -0.785      -0.264
# ma.L3.y        0.0106      0.090      0.118      0.906      -0.166       0.187
# ma.L4.y        0.1210      0.067      1.812      0.070      -0.010       0.252
# ma.L5.y       -0.2904      0.076     -3.802      0.000      -0.440      -0.141
# ma.L6.y       -0.8642      0.080    -10.861      0.000      -1.020      -0.708
# ma.L7.y        0.7901      0.128      6.150      0.000       0.538       1.042
# ma.L8.y        0.2679      0.144      1.857      0.063      -0.015       0.551
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0002           -0.0000j            1.0002           -0.5000
# AR.2           -0.6391           -0.9709j            1.1623           -0.3426
# AR.3           -0.6391           +0.9709j            1.1623            0.3426
# AR.4            0.5372           -0.9118j            1.0582           -0.1653
# AR.5            0.5372           +0.9118j            1.0582            0.1653
# AR.6            1.0178           -0.1914j            1.0356           -0.0296
# AR.7            1.0178           +0.1914j            1.0356            0.0296
# MA.1            1.0005           -0.0010j            1.0005           -0.0002
# MA.2            1.0005           +0.0010j            1.0005            0.0002
# MA.3            0.4710           -0.8821j            1.0000           -0.1719
# MA.4            0.4710           +0.8821j            1.0000            0.1719
# MA.5           -0.5814           -0.8136j            1.0000           -0.3487
# MA.6           -0.5814           +0.8136j            1.0000            0.3487
# MA.7           -1.0000           -0.0000j            1.0000           -0.5000
# MA.8           -3.7295           -0.0000j            3.7295           -0.5000
# -----------------------------------------------------------------------------
# """

# %%
draw(remains - mfit.resid);
# plt.show()
draw(remains);

# %% [markdown]
# # ARIMA на исходные данные

# %%
model2 = ARIMA(series, order=(5,1,5))
mfit2 = model2.fit()
# Out:
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
fig, ax = plt.subplots(figsize=(18, 12))
ax.plot(series);
ax.plot(series[1:] - mfit2.resid);
plt.show()

# %% [markdown]
# #### Остатки после тренда и остатки после аримы

# %%
draw(mfit2.resid);
draw(remains);

# %%
plot_acf(series);
plot_pacf(series);

# %%
min_aic = float('inf')
min_params = ()
min_fit = None
for p, d, q in itertools.product(range(8), (0, 1), (1,)):
    _model = ARIMA(series, order=(p, d, q))
    _mfit = _model.fit()
    final_model = series[d:]-_mfit.resid
    _aic = rp.aic.aic(series.tolist()[d:], final_model.tolist(), 10) / (len(series) - d)
    if _aic < min_aic:
        min_aic = _aic
        min_params = p, d, q
        min_fit = _mfit
    print(p, d, q, _aic)
print('Min', p, d, q, _aic)
# Out:
# 0 0 1 10.77814650880696
# 0 1 1 9.72443672260616
# 1 0 1 9.865250037824078
# 1 1 1 9.722167996471049
# 2 0 1 9.991582485352595
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:716: RuntimeWarning: divide by zero encountered in log
#   invmacoefs = -np.log((1-macoefs)/(1+macoefs))
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/tools/numdiff.py:243: RuntimeWarning: invalid value encountered in subtract
#   **kwargs)).imag/2./hess[i, j]
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/tools/numdiff.py:243: RuntimeWarning: invalid value encountered in multiply
#   **kwargs)).imag/2./hess[i, j]
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:689: RuntimeWarning: invalid value encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:690: RuntimeWarning: invalid value encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /home/utoo/.venv_wrappers/maxim/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# 2 1 1 9.725249791627958
# 3 0 1 9.955401553566123
# 3 1 1 9.718030348243245
# 4 0 1 9.848399665463313
# 4 1 1 9.698932839593294
# 5 0 1 9.844982688717634
# 5 1 1 9.69443284030383
# 6 0 1 9.842583432703325
# 6 1 1 9.692201446403164
# 7 0 1 9.812715580566731
# 7 1 1 9.684991676646533
# Min 7 1 1 9.684991676646533

# %%
min_fit

# %%
rp.aic.aic(series[1:].tolist(), (series[1:]-min_fit.resid).tolist(), 5)/(len(series)-1)
# Out:
# 9.59570596236082

# %%
__series = series.tolist()[:-1] + [series.tolist()[-1]*1.000000000000001]

# %%
rp.aic.aic(series.tolist(), [1400]*len(series), 10) / len(series)
# Out:
# 11.789990250912595

# %%
l2 = np.array([1400]*len(series))

# %%
np.log(((series - l2)**2).sum()/len(series))
# Out:
# 11.612999100470116

# %% [markdown]
# ### Тест CHOW

# %%
draw(series[:26].tolist());
draw([None]*25+series[25:60].tolist())
draw([None]*59+series[59:].tolist());
