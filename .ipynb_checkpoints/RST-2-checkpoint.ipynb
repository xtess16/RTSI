# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
from statsmodels.tsa.stattools import adfuller
import numpy as np
from numpy import polyfit
from scipy import stats

# %%
df = pd.read_csv('./data/RTS-history-USA.csv')

# %%
df[::-1][::25].to_csv('./data-RTS-history-USA25.csv')

# %%
series = np.array([i for i in df.Open[::-1][::25]])
# series_dates = np.array([i for i in df.index[::-1][::25]])

# %% [markdown]
# ### Экспоненциальное сглаживание

# %%
def exponential_smoothing(series, alpha):
    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    
    res = 0
    for s, r in zip(series, result):
        res += (s - r) ** 2
    return result

# %%
def get_polyfit(series, k):
    p = polyfit(range(len(series)), series, k)
    pf = np.poly1d(p)
    return pf(range(len(series)))

# %%
def find_lags(seq, a=1, b=25):
    lags = []
    for lag in range(a, b+1):
        res_lag = pearsonr(seq[: -lag], seq[lag:])[0]
        lags.append(res_lag)
    return lags

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(series, label='Оригинал', color='000', linewidth=3)
for a in [.05, .25, .5, .75, .95]:
    result = exponential_smoothing(series, a)
    plt.plot(result, label=str(a))
plt.legend()
plt.show()

# %%
plt.plot(find_lags(exponential_smoothing(series, .5)));

# %%
adfuller(series)
# Out:
# (-2.670316461994629,
#  0.07931716496293206,
#  0,
#  112,
#  {'1%': -3.4901313156261384,
#   '5%': -2.8877122815688776,
#   '10%': -2.5807296460459184},
#  1212.2077258437034)

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(series, label='Оригинал')
plt.plot(get_polyfit(series, 4), label='Полином')
plt.legend()
plt.show()

# %%
pl = get_polyfit(series, 4)
mean = series.mean()

# %%
top = ((pl-mean)**2).sum()
bottom = ((series-mean)**2).sum()
kf_determ = top/bottom
kf_determ
# Out:
# 0.805586569565061

# %%
kf_determ_adj = 1 - (1 - kf_determ)*((len(series)-1)/(len(series)-5))
kf_determ_adj
# Out:
# 0.7983860721415448

# %%
kf3 = find_lags(exponential_smoothing(series, .5))[2]
kf3 / (1-kf3**2/(len(series)-2))**.5
# Out:
# 0.8779127178547305

# %%
df3 = pd.read_csv('./data/RTS-history-USA.csv', parse_dates=True, index_col='Date')
df3.drop('Unnamed: 0', axis=1, inplace=True)
df3 = df3[::-1][::25]
df3.head()
# Out:
#             Open
# Date
# 2009-01-11   631
# 2009-02-13   611
# 2009-03-24   737
# 2009-04-28   803
# 2009-06-04  1125

# %%
import statsmodels.api as sm

dta = df3.copy()
# deal with missing values. see issue
dta.Open.interpolate(inplace=True)

res = sm.tsa.seasonal_decompose(dta.Open, period=5)
res.plot();

# %%
l = series - get_polyfit(series, 4)

# %%
plt.plot(find_lags(l));

# %%
plt.plot(l);

# %%
(kf_determ/(1-kf_determ))*(len(series)-2)
# Out:
# 459.94820945071734
